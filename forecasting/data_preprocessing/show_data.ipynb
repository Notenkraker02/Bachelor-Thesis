# %%
import os
import sys
current_dir = os.path.dirname(r"C:\Users\JNoot\Documents\University\Bachelor Thesis\New Code\forecasting\data_preprocessing")
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.insert(0, parent_dir)
sys.path.append(os.path.dirname(os.path.abspath(r"C:\Users\JNoot\Documents\University\Bachelor Thesis\New Code\forecasting\data_preprocessing\show_data.ipynb")) + '/..')
from obtain_data import obtainData, plot_volatility

coins = ["Bitcoin", "Ethereum", "Tether", "Binance Coin", "Bitcoin Cash", "Litecoin", "Internet Computer", "Polygon"]

for coin in coins:
    X, Y, X_ridge = obtainData(coin)
    plot_volatility(Y)
# Out:
# Bitcoin
# Ethereum
# Tether
# Binance Coin
# Bitcoin Cash
# Litecoin
# Internet Computer
# Polygon
